# %% [markdown]
# **SISTEMA DE RECOMENDACION**
#
# **CURSO : PROTOTIPADO DE APLICACIONES DE INTELIGENCIA ARTIFICIAL**
#
# **INSTRUCTOR : MOISÉS EVANGELISTA GAMARRA**
#
# dataset tomado de: https://www.kaggle.com/datasets/harshitshankhdhar/imdb-dataset-of-top-1000-movies-and-tv-shows

# %% [markdown]
# **1.- DESCARGA DE DATOS**

# %%
import pandas as pd

imdb = pd.read_csv("/content/sample_data/imdb_top_1000.csv")
imdb.head(10)
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
# 5  https://m.media-amazon.com/images/M/MV5BNzA5ZD...
# 6  https://m.media-amazon.com/images/M/MV5BNGNhMD...
# 7  https://m.media-amazon.com/images/M/MV5BNDE4OT...
# 8  https://m.media-amazon.com/images/M/MV5BMjAxMz...
# 9  https://m.media-amazon.com/images/M/MV5BMmEzNT...
#
#                                     Series_Title Released_Year Certificate  \
# 0                       The Shawshank Redemption          1994           A
# 1                                  The Godfather          1972           A
# 2                                The Dark Knight          2008          UA
# 3                         The Godfather: Part II          1974           A
# ...

# %% [markdown]
# ** 2.- PREPARACIÓN DE DATOS **
#
#  Seleccionar las características de la película.

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.pipeline import Pipeline


# Filter data
##keep_cols = ['Genre', 'Director', 'Star1', 'Star2']
keep_cols = ['Genre', 'Director']
imdb_filtered = imdb.loc[:,keep_cols]

## Pipeline: Es un conjunto de tareas que ocurren en secuencia, 
## donde la salida de una tarea se convierte en la entrada de la siguiente,
## hasta que genera el producto final al final.

# Create pipeline for numerical variables
numeric_pipe = Pipeline([
    ('scaler', StandardScaler())
    ])

# Create pipeline for categorical variable
categorical_pipe = Pipeline([
    ('encoder', OneHotEncoder(drop = 'first'))
    ])

# Create ColumnTransform
col_transf = ColumnTransformer([
    ('numeric', numeric_pipe, imdb_filtered._get_numeric_data().columns.tolist()),
    ('categoric', categorical_pipe, imdb_filtered.select_dtypes('object').columns.tolist()) 
    ])

col_transf_fit = col_transf.fit(imdb_filtered)
imdb_filtered_transf = col_transf_fit.transform(imdb_filtered)
imdb_filtered_transf
# Out:
# <1000x748 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1994 stored elements in Compressed Sparse Row format>

# %%
## KNN= Busca en las observaciones más cercanas a la que se está tratando de predecir y 
## clasifica el punto de interés basado en la mayoría de datos que le rodean
from sklearn.neighbors import NearestNeighbors

n_neighbors=5

nneighbors = NearestNeighbors(n_neighbors = n_neighbors, metric = 'cosine').fit(imdb_filtered_transf)

# %%
dif, ind = nneighbors.kneighbors(imdb_filtered_transf[1])

##print("Liked Film")
##print("="*80)
imdb.loc[ind[0][0], :]
print("Recommended Films")
##print("="*80)
imdb.loc[ind[0][0:], :]
# Out:
# Recommended Films
#                                            Poster_Link  \
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 974  https://m.media-amazon.com/images/M/MV5BNWFlYW...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 180  https://m.media-amazon.com/images/M/MV5BNmVmYz...
# 480  https://m.media-amazon.com/images/M/MV5BYTRkMD...
#
#                 Series_Title Released_Year Certificate  Runtime         Genre  \
# 1              The Godfather          1972           A  175 min  Crime, Drama
# 974  The Godfather: Part III          1990           A  162 min  Crime, Drama
# 3     The Godfather: Part II          1974           A  202 min  Crime, Drama
# 180    To Kill a Mockingbird          1962           U  129 min  Crime, Drama
# 480  Bir Zamanlar Anadolu'da          2011         NaN  157 min  Crime, Drama
#
#      IMDB_Rating                                           Overview  \
# 1            9.2  An organized crime dynasty's aging patriarch t...
# ...
